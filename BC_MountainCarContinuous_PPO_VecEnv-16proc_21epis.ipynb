# %% [markdown]
# # MountainCarContinuous-v0 with PPO, Vectorized Environment
#
#
# ### 1. Create Vectorized Environment

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt

from  collections  import deque
import time
from model import Policy
from ppo import ppo_agent
from storage import RolloutStorage
from utils import get_render_func, get_vec_normalize
from envs import make_vec_envs
from parallelEnv import parallelEnv
import matplotlib.pyplot as plt
# %matplotlib inline

print('gym version: ', gym.__version__)
print('torch version: ', torch.__version__)

seed = 0 
gamma=0.99
num_processes =  16 

device = torch.device("cpu")
print('device: ', device)

envs = parallelEnv('MountainCarContinuous-v0', n=num_processes, seed=seed)

## make_vec_envs -cannot find context for 'forkserver'
## forkserver is only available in Python 3.4+ and only on some Unix platforms (not on Windows).
## envs = make_vec_envs('BipedalWalker-v2', \
##                    seed + 1000, num_processes,
##                    None, None, False, device='cpu', allow_early_resets=False)

max_steps = envs.max_steps
print('max_steps: ', max_steps)

threshold = envs.threshold
print('threshold: ', threshold)
threshold = 2000
print('reassigned threshold: ', threshold)

torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)

dir_chk = 'dir_save_test_BC'
# Out:
# gym version:  0.22.0
# torch version:  2.5.1+cu124
# device:  cpu
# max_steps:  999
# threshold:  99.0
# reassigned threshold:  2000

# %% [markdown]
# ### 2. Instantiate Model, Agent and Storage
#
# Initialize the Policy (model MLPBase), PPO Agent and Rollout Storage.

# %%
## model Policy uses MLPBase
# policy = Policy(envs.observation_space.shape, envs.action_space,\
#         base_kwargs={'recurrent': False})

# 修改policy
policy = Policy(envs.observation_space.shape, envs.action_space,\
        base_kwargs={'recurrent': False})

policy.to(device)

agent = ppo_agent(actor_critic=policy, ppo_epoch=16, num_mini_batch=16,\
                 lr=0.01, eps=1e-5, max_grad_norm=0.5)

rollouts = RolloutStorage(num_steps=max_steps, num_processes=num_processes, \
                        obs_shape=envs.observation_space.shape, action_space=envs.action_space, \
                        recurrent_hidden_state_size=policy.recurrent_hidden_state_size)

obs = envs.reset()
print('type obs: ', type(obs), ', shape obs: ', obs.shape)
obs_t = torch.tensor(obs)
print('type obs_t: ', type(obs_t), ', shape obs_t: ', obs_t.shape)

rollouts.obs[0].copy_(obs_t)
rollouts.to(device)
# Out:
# type obs:  <class 'numpy.ndarray'> , shape obs:  (16, 2)
# type obs_t:  <class 'torch.Tensor'> , shape obs_t:  torch.Size([16, 2])

# %% [markdown]
# ### 3.Save model function

# %%
def save(model, directory, filename, suffix):
    torch.save(model.base.actor.state_dict(), '%s/%s_actor_%s.pth' % (directory, filename, suffix))
    torch.save(model.base.critic.state_dict(), '%s/%s_critic_%s.pth' % (directory, filename, suffix))
    torch.save(model.base.critic_linear.state_dict(), '%s/%s_critic_linear_%s.pth' % (directory, filename, suffix))
    torch.save(model.base, '%s/%s_model_base_%s.pth' % (directory, filename, suffix))
    torch.save(model.dist, '%s/%s_model_dist_%s.pth' % (directory, filename, suffix))
    
limits = [-300, -160, -100, -70, -50, 0, 20, 30, 40, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330]

def return_suffix(j):
    suf = '0'
    for i in range(len(limits)-1):
        if j > limits[i] and j < limits[i+1]:
            suf = str(limits[i+1])
            break
        
        i_last = len(limits)-1    
        if  j > limits[i_last]:
            suf = str(limits[i_last])
            break
    return suf

# %% [markdown]
# ### 4. Train the Agent  with Vectorized Environment

# %%
num_updates=120
gamma = 0.99
tau=0.95
save_interval=30
log_interval= 1 

def ppo_vec_env_train(envs, agent, policy, num_processes, num_steps, rollouts):
    
    time_start = time.time()
    
    n=len(envs.ps)    
    envs.reset()
    
    # start all parallel agents
    print('Number of agents: ', n)
    envs.step([[1]*4]*n)
    
    indices = []
    for i  in range(n):
        indices.append(i)
     
    s = 0
    
    scores_deque = deque(maxlen=100)
    scores_array = []
    avg_scores_array = []    

    for i_episode in range(num_updates):
        
        total_reward = np.zeros(n)
        timestep = 0
        
        done = False
        
        for timestep in range(num_steps):
            
            with torch.no_grad():
                value, actions, action_log_prob, recurrent_hidden_states = \
                   policy.act(
                        rollouts.obs[timestep],
                        rollouts.recurrent_hidden_states[timestep],
                        rollouts.masks[timestep])
                   
                
            obs, rewards, done, _ = envs.step(actions.cpu().detach().numpy())
            
            
            total_reward += rewards  ## this is the list by agents
                        
            # If done then clean the history of observations.
            masks = torch.FloatTensor([[0.0] if done_ else [1.0] for done_ in done])
            obs_t = torch.tensor(obs)
            
            ## Add one dimnesion to tensor, 
            ## This is (unsqueeze(1)) solution for:
            ## RuntimeError: The expanded size of the tensor (1) must match the existing size...
            rewards_t = torch.tensor(rewards).unsqueeze(1)
            rollouts.insert(obs_t, recurrent_hidden_states, actions, action_log_prob, \
                value, rewards_t, masks)
                                
        avg_total_reward = np.mean(total_reward)
        scores_deque.append(avg_total_reward)
        scores_array.append(avg_total_reward)
                
        with torch.no_grad():
            next_value = policy.get_value(rollouts.obs[-1],
                            rollouts.recurrent_hidden_states[-1],
                            rollouts.masks[-1]).detach()

        rollouts.compute_returns(next_value, gamma, tau)
        
        agent.update(rollouts)
        # 改动了一下update
        # agent.update(rollouts, i_episode)

        rollouts.after_update()
        
        avg_score = np.mean(scores_deque)
        avg_scores_array.append(avg_score)

        if i_episode > 0 and i_episode % save_interval == 0:
            print('Saving model, i_episode: ', i_episode, '\n')
            suf = return_suffix(avg_score)
            save(policy, dir_chk, 'we0', suf)

        
        if i_episode % log_interval == 0 and len(scores_deque) > 1:            
            prev_s = s
            s = (int)(time.time() - time_start)
            t_del = s - prev_s
            print('Ep. {}, Timesteps {}, Score.Agents: {:.2f}, Avg.Score: {:.2f}, Time: {:02}:{:02}:{:02}, \
Interval: {:02}:{:02}'\
                   .format(i_episode, timestep+1, \
                        avg_total_reward, avg_score, s//3600, s%3600//60, s%60, t_del%3600//60, t_del%60)) 
    
        if len(scores_deque) > 1 and avg_score > threshold:   
            print('Environment solved with Average Score: ',  avg_score )
            break
        
    
    return scores_array, avg_scores_array

# %%
envs = parallelEnv('MountainCarContinuous-v0', n=num_processes, seed=seed, dense=True)
scores, avg_scores = ppo_vec_env_train(envs, agent, policy, num_processes, max_steps, rollouts)
save(model=policy,directory=dir_chk,filename='we0',suffix='pre_train')
# Out:
# Number of agents:  16
# Ep. 1, Timesteps 999, Score.Agents: -159.81, Avg.Score: -152.39, Time: 00:00:06, Interval: 00:06
# Ep. 2, Timesteps 999, Score.Agents: -172.90, Avg.Score: -159.23, Time: 00:00:08, Interval: 00:02
# Ep. 3, Timesteps 999, Score.Agents: -136.59, Avg.Score: -153.57, Time: 00:00:11, Interval: 00:03
# Ep. 4, Timesteps 999, Score.Agents: -162.86, Avg.Score: -155.43, Time: 00:00:14, Interval: 00:03
# Ep. 5, Timesteps 999, Score.Agents: -152.47, Avg.Score: -154.93, Time: 00:00:17, Interval: 00:03
# Ep. 6, Timesteps 999, Score.Agents: -152.88, Avg.Score: -154.64, Time: 00:00:20, Interval: 00:03
# Ep. 7, Timesteps 999, Score.Agents: -130.90, Avg.Score: -151.67, Time: 00:00:24, Interval: 00:04
# Ep. 8, Timesteps 999, Score.Agents: -143.57, Avg.Score: -150.77, Time: 00:00:27, Interval: 00:03
# Ep. 9, Timesteps 999, Score.Agents: -86.43, Avg.Score: -144.34, Time: 00:00:30, Interval: 00:03
# Ep. 10, Timesteps 999, Score.Agents: -143.44, Avg.Score: -144.26, Time: 00:00:34, Interval: 00:04
# Ep. 11, Timesteps 999, Score.Agents: -124.58, Avg.Score: -142.62, Time: 00:00:38, Interval: 00:04
# Ep. 12, Timesteps 999, Score.Agents: -145.70, Avg.Score: -142.85, Time: 00:00:41, Interval: 00:03
# Ep. 13, Timesteps 999, Score.Agents: -115.54, Avg.Score: -140.90, Time: 00:00:45, Interval: 00:04
# Ep. 14, Timesteps 999, Score.Agents: -138.81, Avg.Score: -140.76, Time: 00:00:48, Interval: 00:03
# Ep. 15, Timesteps 999, Score.Agents: -129.18, Avg.Score: -140.04, Time: 00:00:52, Interval: 00:04
# Ep. 16, Timesteps 999, Score.Agents: -112.27, Avg.Score: -138.41, Time: 00:00:56, Interval: 00:04
# Ep. 17, Timesteps 999, Score.Agents: -113.55, Avg.Score: -137.02, Time: 00:01:00, Interval: 00:04
# Ep. 18, Timesteps 999, Score.Agents: -111.51, Avg.Score: -135.68, Time: 00:01:03, Interval: 00:03
# Ep. 19, Timesteps 999, Score.Agents: -108.37, Avg.Score: -134.32, Time: 00:01:07, Interval: 00:04
# Ep. 20, Timesteps 999, Score.Agents: -101.49, Avg.Score: -132.75, Time: 00:01:10, Interval: 00:03
# Ep. 21, Timesteps 999, Score.Agents: -107.27, Avg.Score: -131.60, Time: 00:01:14, Interval: 00:04
# Ep. 22, Timesteps 999, Score.Agents: -82.21, Avg.Score: -129.45, Time: 00:01:18, Interval: 00:04
# Ep. 23, Timesteps 999, Score.Agents: -87.56, Avg.Score: -127.70, Time: 00:01:21, Interval: 00:03
# Ep. 24, Timesteps 999, Score.Agents: -81.55, Avg.Score: -125.86, Time: 00:01:25, Interval: 00:04
# Ep. 101, Timesteps 999, Score.Agents: 771.67, Avg.Score: -1045.91, Time: 00:05:16, Interval: 00:03
# Ep. 102, Timesteps 999, Score.Agents: 796.38, Avg.Score: -1036.21, Time: 00:05:18, Interval: 00:02
# Ep. 103, Timesteps 999, Score.Agents: 780.68, Avg.Score: -1027.04, Time: 00:05:21, Interval: 00:03
# Ep. 104, Timesteps 999, Score.Agents: 947.93, Avg.Score: -1015.93, Time: 00:05:24, Interval: 00:03
# Ep. 105, Timesteps 999, Score.Agents: 1067.58, Avg.Score: -1003.73, Time: 00:05:26, Interval: 00:02
# Ep. 106, Timesteps 999, Score.Agents: 1090.66, Avg.Score: -991.30, Time: 00:05:29, Interval: 00:03
# Ep. 107, Timesteps 999, Score.Agents: 1203.95, Avg.Score: -977.95, Time: 00:05:31, Interval: 00:02
# Ep. 108, Timesteps 999, Score.Agents: 1230.75, Avg.Score: -964.21, Time: 00:05:34, Interval: 00:03
# Ep. 109, Timesteps 999, Score.Agents: 1232.50, Avg.Score: -951.02, Time: 00:05:37, Interval: 00:03
# Ep. 110, Timesteps 999, Score.Agents: 1270.05, Avg.Score: -936.88, Time: 00:05:39, Interval: 00:02
# Ep. 111, Timesteps 999, Score.Agents: 1509.03, Avg.Score: -920.55, Time: 00:05:42, Interval: 00:03
# Ep. 112, Timesteps 999, Score.Agents: 1239.38, Avg.Score: -906.70, Time: 00:05:45, Interval: 00:03
# Ep. 113, Timesteps 999, Score.Agents: 1294.75, Avg.Score: -892.59, Time: 00:05:47, Interval: 00:02
# Ep. 114, Timesteps 999, Score.Agents: 1332.09, Avg.Score: -877.88, Time: 00:05:50, Interval: 00:03
# Ep. 115, Timesteps 999, Score.Agents: 1383.22, Avg.Score: -862.76, Time: 00:05:53, Interval: 00:03
# Ep. 116, Timesteps 999, Score.Agents: 1481.74, Avg.Score: -846.82, Time: 00:05:55, Interval: 00:02
# Ep. 117, Timesteps 999, Score.Agents: 1498.82, Avg.Score: -830.70, Time: 00:05:58, Interval: 00:03
# Ep. 118, Timesteps 999, Score.Agents: 1533.19, Avg.Score: -814.25, Time: 00:06:01, Interval: 00:03
# Ep. 119, Timesteps 999, Score.Agents: 1472.08, Avg.Score: -798.44, Time: 00:06:03, Interval: 00:02

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  120 , len of avg_scores:  120

# %%
envs = parallelEnv('MountainCarContinuous-v0', n=num_processes, seed=seed, dense=False)
num_updates=50
gamma = 0.99
tau=0.95
save_interval=30
log_interval= 1 

def ppo_vec_env_train_critic(envs, agent, policy, num_processes, num_steps, rollouts):
    
    time_start = time.time()
    
    n=len(envs.ps)    
    envs.reset()
    
    # start all parallel agents
    print('Number of agents: ', n)
    envs.step([[1]*4]*n)
    
    indices = []
    for i  in range(n):
        indices.append(i)
     
    s = 0
    
    scores_deque = deque(maxlen=100)
    scores_array = []
    avg_scores_array = []    

    for i_episode in range(num_updates):
        
        total_reward = np.zeros(n)
        timestep = 0
        
        done = False
        
        for timestep in range(num_steps):
            
            with torch.no_grad():
                value, actions, action_log_prob, recurrent_hidden_states = \
                   policy.act(
                        rollouts.obs[timestep],
                        rollouts.recurrent_hidden_states[timestep],
                        rollouts.masks[timestep])
                   
                
            obs, rewards, done, _ = envs.step(actions.cpu().detach().numpy())
            
            
            total_reward += rewards  ## this is the list by agents
                        
            # If done then clean the history of observations.
            masks = torch.FloatTensor([[0.0] if done_ else [1.0] for done_ in done])
            obs_t = torch.tensor(obs)
            
            ## Add one dimnesion to tensor, 
            ## This is (unsqueeze(1)) solution for:
            ## RuntimeError: The expanded size of the tensor (1) must match the existing size...
            rewards_t = torch.tensor(rewards).unsqueeze(1)
            rollouts.insert(obs_t, recurrent_hidden_states, actions, action_log_prob, \
                value, rewards_t, masks)
                                
        avg_total_reward = np.mean(total_reward)
        scores_deque.append(avg_total_reward)
        scores_array.append(avg_total_reward)
                
        with torch.no_grad():
            next_value = policy.get_value(rollouts.obs[-1],
                            rollouts.recurrent_hidden_states[-1],
                            rollouts.masks[-1]).detach()

        rollouts.compute_returns(next_value, gamma, tau)
        
        agent.update_critic_only(rollouts)
        # 改动了一下update
        # agent.update(rollouts, i_episode)

        rollouts.after_update()
        
        avg_score = np.mean(scores_deque)
        avg_scores_array.append(avg_score)

        if i_episode > 0 and i_episode % save_interval == 0:
            print('Saving model, i_episode: ', i_episode, '\n')
            suf = return_suffix(avg_score)
            save(policy, dir_chk, 'we0', suf)

        
        if i_episode % log_interval == 0 and len(scores_deque) > 1:            
            prev_s = s
            s = (int)(time.time() - time_start)
            t_del = s - prev_s
            print('Ep. {}, Timesteps {}, Score.Agents: {:.2f}, Avg.Score: {:.2f}, Time: {:02}:{:02}:{:02}, \
Interval: {:02}:{:02}'\
                   .format(i_episode, timestep+1, \
                        avg_total_reward, avg_score, s//3600, s%3600//60, s%60, t_del%3600//60, t_del%60)) 
    
        if len(scores_deque) > 1 and avg_score > threshold:   
            print('Environment solved with Average Score: ',  avg_score )
            break
        
    
    return scores_array, avg_scores_array

scores, avg_scores = ppo_vec_env_train_critic(envs, agent, policy, num_processes, max_steps, rollouts)
save(model=policy,directory=dir_chk,filename='we0',suffix='value_adjust')
# Out:
# Number of agents:  16
# Ep. 1, Timesteps 999, Score.Agents: 707.03, Avg.Score: 686.97, Time: 00:00:05, Interval: 00:05
# Ep. 2, Timesteps 999, Score.Agents: 706.52, Avg.Score: 693.49, Time: 00:00:07, Interval: 00:02
# Ep. 3, Timesteps 999, Score.Agents: 705.77, Avg.Score: 696.56, Time: 00:00:09, Interval: 00:02
# Ep. 4, Timesteps 999, Score.Agents: 729.74, Avg.Score: 703.20, Time: 00:00:12, Interval: 00:03
# Ep. 31, Timesteps 999, Score.Agents: 716.03, Avg.Score: 716.19, Time: 00:01:17, Interval: 00:03
# Ep. 32, Timesteps 999, Score.Agents: 713.02, Avg.Score: 716.09, Time: 00:01:19, Interval: 00:02
# Ep. 33, Timesteps 999, Score.Agents: 682.42, Avg.Score: 715.10, Time: 00:01:21, Interval: 00:02
# Ep. 34, Timesteps 999, Score.Agents: 729.98, Avg.Score: 715.53, Time: 00:01:24, Interval: 00:03
# Ep. 35, Timesteps 999, Score.Agents: 701.02, Avg.Score: 715.13, Time: 00:01:26, Interval: 00:02
# Ep. 36, Timesteps 999, Score.Agents: 746.49, Avg.Score: 715.97, Time: 00:01:29, Interval: 00:03
# Ep. 37, Timesteps 999, Score.Agents: 685.72, Avg.Score: 715.18, Time: 00:01:31, Interval: 00:02
# Ep. 38, Timesteps 999, Score.Agents: 733.15, Avg.Score: 715.64, Time: 00:01:33, Interval: 00:02
# Ep. 39, Timesteps 999, Score.Agents: 727.26, Avg.Score: 715.93, Time: 00:01:36, Interval: 00:03
# Ep. 40, Timesteps 999, Score.Agents: 714.02, Avg.Score: 715.88, Time: 00:01:38, Interval: 00:02
# Ep. 41, Timesteps 999, Score.Agents: 705.97, Avg.Score: 715.65, Time: 00:01:41, Interval: 00:03
# Ep. 42, Timesteps 999, Score.Agents: 714.32, Avg.Score: 715.62, Time: 00:01:43, Interval: 00:02
# Ep. 43, Timesteps 999, Score.Agents: 723.78, Avg.Score: 715.80, Time: 00:01:45, Interval: 00:02
# Ep. 44, Timesteps 999, Score.Agents: 748.81, Avg.Score: 716.53, Time: 00:01:48, Interval: 00:03
# Ep. 45, Timesteps 999, Score.Agents: 713.13, Avg.Score: 716.46, Time: 00:01:50, Interval: 00:02
# Ep. 46, Timesteps 999, Score.Agents: 687.96, Avg.Score: 715.85, Time: 00:01:53, Interval: 00:03
# Ep. 47, Timesteps 999, Score.Agents: 735.99, Avg.Score: 716.27, Time: 00:01:55, Interval: 00:02
# Ep. 48, Timesteps 999, Score.Agents: 699.38, Avg.Score: 715.93, Time: 00:01:57, Interval: 00:02
# Ep. 49, Timesteps 999, Score.Agents: 737.66, Avg.Score: 716.36, Time: 00:02:00, Interval: 00:03

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  50 , len of avg_scores:  50

# %%
import torch.optim as optim
agent.optimizer = optim.Adam(agent.actor_critic.parameters(), lr=0.003, eps=1e-5)
num_updates=50
scores, avg_scores = ppo_vec_env_train(envs, agent, policy, num_processes, max_steps, rollouts)
save(model=policy,directory=dir_chk,filename='we0',suffix='final')
# Out:
# Number of agents:  16
# Ep. 1, Timesteps 999, Score.Agents: 738.73, Avg.Score: 687.44, Time: 00:00:05, Interval: 00:05
# Ep. 28, Timesteps 999, Score.Agents: 889.67, Avg.Score: 840.99, Time: 00:01:16, Interval: 00:03
# Ep. 29, Timesteps 999, Score.Agents: 877.90, Avg.Score: 842.22, Time: 00:01:19, Interval: 00:03
# Saving model, i_episode:  30
#
# Ep. 30, Timesteps 999, Score.Agents: 848.61, Avg.Score: 842.43, Time: 00:01:22, Interval: 00:03
# Ep. 31, Timesteps 999, Score.Agents: 927.87, Avg.Score: 845.10, Time: 00:01:26, Interval: 00:04
# Ep. 32, Timesteps 999, Score.Agents: 867.98, Avg.Score: 845.79, Time: 00:01:29, Interval: 00:03
# Ep. 33, Timesteps 999, Score.Agents: 874.00, Avg.Score: 846.62, Time: 00:01:33, Interval: 00:04
# Ep. 34, Timesteps 999, Score.Agents: 918.60, Avg.Score: 848.68, Time: 00:01:36, Interval: 00:03
# Ep. 35, Timesteps 999, Score.Agents: 887.80, Avg.Score: 849.76, Time: 00:01:40, Interval: 00:04
# Ep. 36, Timesteps 999, Score.Agents: 917.99, Avg.Score: 851.61, Time: 00:01:43, Interval: 00:03
# Ep. 37, Timesteps 999, Score.Agents: 906.87, Avg.Score: 853.06, Time: 00:01:47, Interval: 00:04
# Ep. 38, Timesteps 999, Score.Agents: 879.40, Avg.Score: 853.74, Time: 00:01:50, Interval: 00:03
# Ep. 39, Timesteps 999, Score.Agents: 897.35, Avg.Score: 854.83, Time: 00:01:54, Interval: 00:04
# Ep. 40, Timesteps 999, Score.Agents: 907.95, Avg.Score: 856.12, Time: 00:01:58, Interval: 00:04
# Ep. 41, Timesteps 999, Score.Agents: 910.55, Avg.Score: 857.42, Time: 00:02:01, Interval: 00:03
# Ep. 42, Timesteps 999, Score.Agents: 842.56, Avg.Score: 857.07, Time: 00:02:05, Interval: 00:04
# Ep. 43, Timesteps 999, Score.Agents: 885.06, Avg.Score: 857.71, Time: 00:02:08, Interval: 00:03
# Ep. 44, Timesteps 999, Score.Agents: 872.29, Avg.Score: 858.03, Time: 00:02:12, Interval: 00:04
# Ep. 45, Timesteps 999, Score.Agents: 916.63, Avg.Score: 859.31, Time: 00:02:15, Interval: 00:03
# Ep. 46, Timesteps 999, Score.Agents: 898.49, Avg.Score: 860.14, Time: 00:02:19, Interval: 00:04
# Ep. 47, Timesteps 999, Score.Agents: 886.51, Avg.Score: 860.69, Time: 00:02:22, Interval: 00:03
# Ep. 48, Timesteps 999, Score.Agents: 879.35, Avg.Score: 861.07, Time: 00:02:26, Interval: 00:04
# Ep. 49, Timesteps 999, Score.Agents: 888.95, Avg.Score: 861.63, Time: 00:02:29, Interval: 00:03

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print('length of scores: ', len(scores), ', len of avg_scores: ', len(avg_scores))

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores, label="Score")
plt.plot(np.arange(1, len(avg_scores)+1), avg_scores, label="Avg on 100 episodes")
plt.legend(bbox_to_anchor=(1.05, 1)) 
plt.ylabel('Score')
plt.xlabel('Episodes #')
plt.show()
# Out:
# length of scores:  50 , len of avg_scores:  50
